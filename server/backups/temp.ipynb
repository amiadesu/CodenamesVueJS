# %%
with open("./words_.txt", "r+", encoding="utf-8") as f:
    data = f.read()
data = data.split(", ")
print(data)
# Out:
# ['абзац', 'абонемент', 'авария', 'август', 'австралия', 'автобус', 'автомат', 'автомобиль', 'автор', 'агент', 'ад', 'адвокат', 'адрес', 'азия', 'академия', 'аккорд', 'аккумулятор', 'акт', 'актер', 'актриса', 'акцент', 'акция', 'алкоголь', 'аллея', 'альбом', 'альпы', 'америка', 'анализ', 'ангел', 'англия', 'анекдот', 'антарктида', 'анчоус', 'апельсин', 'апостол', 'аппарат', 'аппетит', 'апрель', 'аптека', 'аренда', 'арест', 'арка', 'арктика', 'армия', 'аромат', 'артист', 'архив', 'архитектор', 'аспирантура', 'аспирин', 'ассортимент', 'асфальт', 'атака', 'атмосфера', 'аудитория', 'африка', 'аэродром', 'аэропорт', 'баба', 'бабочка', 'бабушка', 'база', 'базар', 'байкал', 'балалайка', 'балет', 'балкон', 'баллон', 'банан', 'бандероль', 'бандит', 'банк', 'банка', 'баня', 'бар', 'барабан', 'барак', 'барахло', 'барон', 'барышня', 'бас', 'бассейн', 'батальон', 'батарея', 'батон', 'батюшка', 'башка', 'башня', 'баян', 'бег', 'беда', 'бедняга', 'бедро', 'бездна', 'безобразие', 'безумие', 'белка', 
# ...

# %%
res = ""
for i in data:
    res += i + "\n"
with open("./res.txt", "w+", encoding="utf-8") as f:
    f.write(res)
res
# Out:
# 'абзац\nабонемент\nавария\nавгуст\nавстралия\nавтобус\nавтомат\nавтомобиль\nавтор\nагент\nад\nадвокат\nадрес\nазия\nакадемия\nаккорд\nаккумулятор\nакт\nактер\nактриса\nакцент\nакция\nалкоголь\nаллея\nальбом\nальпы\nамерика\nанализ\nангел\nанглия\nанекдот\nантарктида\nанчоус\nапельсин\nапостол\nаппарат\nаппетит\nапрель\nаптека\nаренда\nарест\nарка\nарктика\nармия\nаромат\nартист\nархив\nархитектор\nаспирантура\nаспирин\nассортимент\nасфальт\nатака\nатмосфера\nаудитория\nафрика\nаэродром\nаэропорт\nбаба\nбабочка\nбабушка\nбаза\nбазар\nбайкал\nбалалайка\nбалет\nбалкон\nбаллон\nбанан\nбандероль\nбандит\nбанк\nбанка\nбаня\nбар\nбарабан\nбарак\nбарахло\nбарон\nбарышня\nбас\nбассейн\nбатальон\nбатарея\nбатон\nбатюшка\nбашка\nбашня\nбаян\nбег\nбеда\nбедняга\nбедро\nбездна\nбезобразие\nбезумие\nбелка\nбельгия\nбелье\nбензин\nберег\nбереза\nбес\nбеседа\nбиблиотека\nбизнес\nбилет\nбинокль\nбиология\nбитва\nблаго\nбланк\nблат\nблеск\nблизость\nблин\nблок\nблокнот\nблондинка\nблюдо\nбобер\nбог\nб
# ...
